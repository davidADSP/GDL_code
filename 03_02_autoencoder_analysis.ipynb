# %% [markdown]
# # Autoencoder Analysis

# %% [markdown]
# ## imports

# %%
import numpy as np
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy.stats import norm

from models.AE import Autoencoder
from utils.loaders import load_mnist, load_model
# Out:
# /Users/davidfoster/.virtualenvs/gdl/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
# run params
section = 'vae'
run_id = '0001'
data_name = 'digits'
run_folder = 'run/{}/'.format(section)
run_folder += '_'.join([run_id, data_name])

# %% [markdown]
# ## Load the data

# %%
(x_train, y_train), (x_test, y_test) = load_mnist()

# %% [markdown]
# ## Load the model architecture

# %%
AE = load_model(Autoencoder, run_folder)

# %% [markdown]
# ## reconstructing original paintings

# %%
n_to_show = 10
example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]

z_points = AE.encoder.predict(example_images)

reconst_images = AE.decoder.predict(z_points)

fig = plt.figure(figsize=(15, 3))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(n_to_show):
    img = example_images[i].squeeze()
    ax = fig.add_subplot(2, n_to_show, i+1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_points[i],1)), fontsize=10, ha='center', transform=ax.transAxes)   
    ax.imshow(img, cmap='gray_r')

for i in range(n_to_show):
    img = reconst_images[i].squeeze()
    ax = fig.add_subplot(2, n_to_show, i+n_to_show+1)
    ax.axis('off')
    ax.imshow(img, cmap='gray_r')

# %% [markdown]
# ## Mr N. Coder's wall

# %%
n_to_show = 5000
grid_size = 15
figsize = 12

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = AE.encoder.predict(example_images)

min_x = min(z_points[:, 0])
max_x = max(z_points[:, 0])
min_y = min(z_points[:, 1])
max_y = max(z_points[:, 1])

plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1], c='black', alpha=0.5, s=2)
plt.show()

# %% [markdown]
# ### The new generated art exhibition

# %%
figsize = 5

plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1], c='black', alpha=0.5, s=2)

grid_size = 10
grid_depth = 3
figsize = 15

x = np.random.uniform(min_x,max_x, size = grid_size * grid_depth)
y = np.random.uniform(min_y,max_y, size = grid_size * grid_depth)
z_grid = np.array(list(zip(x, y)))
reconst = AE.decoder.predict(z_grid)

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'red', alpha=1, s=20)
plt.show()

fig = plt.figure(figsize=(figsize, grid_depth))
fig.subplots_adjust(hspace=0.4, wspace=0.4)

for i in range(grid_size*grid_depth):
    ax = fig.add_subplot(grid_depth, grid_size, i+1)
    ax.axis('off')
    ax.text(0.5, -0.35, str(np.round(z_grid[i],1)), fontsize=10, ha='center', transform=ax.transAxes)
    
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')

# %%
n_to_show = 5000
grid_size = 15
figsize = 12

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = AE.encoder.predict(example_images)

plt.figure(figsize=(figsize, figsize))
plt.scatter(z_points[:, 0] , z_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=2)
plt.colorbar()
plt.show()

# %%
n_to_show = 5000
grid_size = 20
figsize = 8

example_idx = np.random.choice(range(len(x_test)), n_to_show)
example_images = x_test[example_idx]
example_labels = y_test[example_idx]

z_points = AE.encoder.predict(example_images)

plt.figure(figsize=(5, 5))
plt.scatter(z_points[:, 0] , z_points[:, 1] , cmap='rainbow' , c= example_labels
            , alpha=0.5, s=2)
plt.colorbar()

# x = norm.ppf(np.linspace(0.05, 0.95, 10))
# y = norm.ppf(np.linspace(0.05, 0.95, 10))
x = np.linspace(min(z_points[:, 0]), max(z_points[:, 0]), grid_size)
y = np.linspace(max(z_points[:, 1]), min(z_points[:, 1]), grid_size)
xv, yv = np.meshgrid(x, y)
xv = xv.flatten()
yv = yv.flatten()
z_grid = np.array(list(zip(xv, yv)))

reconst = AE.decoder.predict(z_grid)

plt.scatter(z_grid[:, 0] , z_grid[:, 1], c = 'black'#, cmap='rainbow' , c= example_labels
            , alpha=1, s=5)




plt.show()


fig = plt.figure(figsize=(figsize, figsize))
fig.subplots_adjust(hspace=0.4, wspace=0.4)
for i in range(grid_size**2):
    ax = fig.add_subplot(grid_size, grid_size, i+1)
    ax.axis('off')
    ax.imshow(reconst[i, :,:,0], cmap = 'Greys')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-320aad55a910> in <module>
#      37 fig.subplots_adjust(hspace=0.4, wspace=0.4)
#      38 for i in range(grid_size**2):
# ---> 39     ax = fig.add_subplot(grid_size, grid_size, i+1)
#      40     ax.axis('off')
#      41     ax.imshow(reconst[i, :,:,0], cmap = 'Greys')
#
# ~/.virtualenvs/gdl/lib/python3.6/site-packages/matplotlib/figure.py in add_subplot(self, *args, **kwargs)
#    1368                     self._axstack.remove(ax)
#    1369
# -> 1370             a = subplot_class_factory(projection_class)(self, *args, **kwargs)
#    1371         self._axstack.add(key, a)
#    1372         self.sca(a)
#
# ~/.virtualenvs/gdl/lib/python3.6/site-packages/matplotlib/axes/_subplots.py in __init__(self, fig, *args, **kwargs)
#      68
#      69         # _axes_class is set in the subplot_class_factory
# ---> 70         self._axes_class.__init__(self, fig, self.figbox, **kwargs)
#      71         # add a layout box to this, for both the full axis, and the poss
#      72         # of the axis.  We need both because the axes may become smaller
#
# ~/.virtualenvs/gdl/lib/python3.6/site-packages/matplotlib/axes/_base.py in __init__(self, fig, rect, facecolor, frameon, sharex, sharey, label, xscale, yscale, **kwargs)
#     481         self._rasterization_zorder = None
#     482         self._connected = {}  # a dict from events to (id, func)
# --> 483         self.cla()
#     484
#     485         # funcs used to format x and y - fall back on major formatters
#
# ~/.virtualenvs/gdl/lib/python3.6/site-packages/matplotlib/axes/_base.py in cla(self)
#    1038         self.containers = []
#    1039
# -> 1040         self.grid(False)  # Disable grid on init to use rcParameter
#    1041         self.grid(self._gridOn, which=rcParams['axes.grid.which'],
#    1042                   axis=rcParams['axes.grid.axis'])
#
# ~/.virtualenvs/gdl/lib/python3.6/site-packages/matplotlib/axes/_base.py in grid(self, b, which, axis, **kwargs)
#    2719
#    2720         if axis == 'x' or axis == 'both':
# -> 2721             self.xaxis.grid(b, which=which, **kwargs)
#    2722         if axis == 'y' or axis == 'both':
#    2723             self.yaxis.grid(b, which=which, **kwargs)
#
# ~/.virtualenvs/gdl/lib/python3.6/site-packages/matplotlib/axis.py in grid(self, b, which, **kwargs)
#    1455                 self._gridOnMajor = b
#    1456             self.set_tick_params(which='major', gridOn=self._gridOnMajor,
# -> 1457                                  **gridkw)
#    1458         self.stale = True
#    1459
#
# ~/.virtualenvs/gdl/lib/python3.6/site-packages/matplotlib/axis.py in set_tick_params(self, which, reset, **kw)
#     861             if which == 'major' or which == 'both':
#     862                 for tick in self.majorTicks:
# --> 863                     tick._apply_params(**self._major_tick_kw)
#     864             if which == 'minor' or which == 'both':
#     865                 for tick in self.minorTicks:
#
# ~/.virtualenvs/gdl/lib/python3.6/site-packages/matplotlib/axis.py in _apply_params(self, **kw)
#     377                     if k in ['labelsize', 'labelcolor']}
#     378         self.label1.set(**label_kw)
# --> 379         self.label2.set(**label_kw)
#     380         for k, v in label_kw.items():
#     381             # for labelsize the text objects covert str ('small')
#
# ~/.virtualenvs/gdl/lib/python3.6/site-packages/matplotlib/artist.py in set(self, **kwargs)
#    1013                    key=lambda x: (self._prop_order.get(x[0], 0), x[0])))
#    1014
# -> 1015         return self.update(props)
#    1016
#    1017     def findobj(self, match=None, include_self=True):
#
# ~/.virtualenvs/gdl/lib/python3.6/site-packages/matplotlib/text.py in update(self, kwargs)
#     185         sentinel = object()  # bbox can be None, so use another sentinel.
#     186         bbox = kwargs.pop("bbox", sentinel)
# --> 187         super().update(kwargs)
#     188         if bbox is not sentinel:
#     189             self.set_bbox(bbox)
#
# ~/.virtualenvs/gdl/lib/python3.6/site-packages/matplotlib/artist.py in update(self, props)
#     913                 return func(v)
#     914
# --> 915         with cbook._setattr_cm(self, eventson=False):
#     916             ret = [_update_property(self, k, v) for k, v in props.items()]
#     917
#
# KeyboardInterrupt:
